# %%
import numpy as np

# some_file.py
import sys
sys.path.insert(0, '../src/easyesn/')

# %%
from easyesn import ESNOptimizer
from easyesn import RegressionESN
from easyesn import GridSearchOptimizer
from easyesn import helper as hlp
import matplotlib.pyplot as plt
# Out:
# Using Numpy backend.

# %%
inputLength = 10000
n = 1000
x = np.empty((n, inputLength))
y = np.empty((n, 1))
domain = np.linspace(0, 4*np.pi, inputLength)

for i in range(n):
    y[i, 0] = np.random.rand()*10
    x[i] = y[i, 0]*2*np.sin(domain)
    
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
esn = RegressionESN(n_input=1, n_output=1, n_reservoir=50, leakingRate=0.2, regression_parameters=[1e-2], solver="lsqr")

# %%
esn.fit(x_train, y_train, transientTime=100, verbose=1)
# Out:
# 100% (670 of 670) |#######################| Elapsed Time: 0:03:42 Time: 0:03:42
# 2.889740172755761

# %%
y_test_pred = esn.predict(x_test, transientTime=100, verbose=1)
y_test_pred
# Out:
# 100% (330 of 330) |#######################| Elapsed Time: 0:01:50 Time: 0:01:50
# array([[ 3.54809086],
#        [ 5.8348159 ],
#        [ 1.95492818],
#        [ 6.02757828],
#        [ 7.96760406],
#        [ 6.4221916 ],
#        [ 1.93913802],
#        [ 4.11296975],
#        [ 2.38576551],
#        [ 6.61691265],
#        [ 4.6245764 ],
#        [ 6.97764417],
#        [ 1.96543873],
#        [ 0.69567237],
#        [ 6.90190507],
#        [ 5.48419954],
#        [ 6.14791155],
#        [ 1.06412709],
#        [ 6.59473457],
#        [ 3.76838424],
#        [ 5.82390598],
#        [ 7.71307174],
#        [ 7.48994852],
#        [ 1.19815189],
#        [ 6.96470797],
#        [ 3.96296901],
#        [ 7.36975804],
#        [ 4.24923881],
#        [ 1.96222836],
#        [ 5.07494404],
#        [ 3.38502857],
#        [ 1.0836312 ],
#        [ 7.06527984],
#        [ 5.93464673],
#        [ 6.12408948],
#        [ 4.88208876],
#        [ 2.22270529],
#        [ 7.55306558],
#        [ 7.92003424],
#        [ 3.61474169],
#        [ 7.68247839],
#        [ 2.2862632 ],
#        [ 7.02285011],
#        [ 2.96713472],
#        [ 7.15739504],
#        [ 6.38910911],
#        [ 7.47743155],
#        [ 7.21245209],
#        [ 1.01054008],
#        [ 7.61347872],
#        [ 4.28184721],
#        [ 7.1183242 ],
#        [ 6.32721273],
#        [ 0.43455908],
#        [ 4.19625088],
#        [ 6.93757045],
#        [ 7.49464263],
#        [ 7.20078898],
#        [ 0.65602327],
#        [ 7.57963628],
#        [ 1.56134696],
#        [ 7.27178756],
#        [ 3.85052712],
#        [ 6.33039532],
#        [ 7.48131955],
#        [ 4.15996771],
#        [ 6.43149906],
#        [ 2.90410816],
#        [ 0.31124248],
#        [ 0.76870234],
#        [ 6.68362968],
#        [ 1.70916533],
#        [ 6.65489312],
#        [ 5.48519124],
#        [ 5.03917155],
#        [ 6.29520062],
#        [ 6.26471257],
#        [ 8.04390659],
#        [ 7.5518963 ],
#        [ 3.96198444],
#        [ 6.24848729],
#        [ 2.98687555],
#        [ 6.89871664],
#        [ 5.83878472],
#        [ 7.95976331],
#        [ 0.61509709],
#        [ 3.37587045],
#        [ 0.69856842],
#        [ 6.30148189],
#        [ 4.4753432 ],
#        [ 6.54808191],
#        [ 3.05529874],
#        [ 7.30635976],
#        [ 4.6592008 ],
#        [ 8.09040974],
#        [ 7.94621813],
#        [ 6.85906125],
#        [ 7.90151481],
#        [ 6.60594006],
#        [ 2.3523553 ],
#        [ 3.89969584],
#        [ 6.7991799 ],
#        [ 5.92723635],
#        [ 5.13882378],
#        [ 6.21583804],
#        [ 7.98456224],
#        [ 6.19927042],
#        [ 1.89657188],
#        [ 7.80038837],
#        [ 3.56749777],
#        [ 5.5347317 ],
#        [ 7.40074431],
#        [ 3.91153138],
#        [ 2.69296181],
#        [ 5.47180065],
#        [ 6.38779351],
#        [ 3.87557563],
#        [ 7.59914986],
#        [ 6.42120672],
#        [ 5.87844589],
#        [ 6.30895643],
#        [ 4.68360372],
#        [ 7.84872215],
#        [ 2.42651659],
#        [ 7.14372739],
#        [ 7.95720324],
#        [ 7.89826086],
#        [ 3.79473355],
#        [ 5.48857408],
#        [ 5.31746408],
#        [ 6.01340049],
#        [ 0.87615518],
#        [ 3.7206795 ],
#        [ 3.0305515 ],
#        [ 5.92906389],
#        [ 1.71382685],
#        [ 6.63214935],
#        [ 3.57638509],
#        [ 7.15074353],
#        [ 2.50923628],
#        [ 7.99946185],
#        [ 4.80624181],
#        [ 7.13971141],
#        [ 5.11646891],
#        [ 5.12347672],
#        [ 6.55388921],
#        [ 3.73066709],
#        [ 5.85594993],
#        [ 7.53939311],
#        [ 7.75984325],
#        [ 3.98646901],
#        [ 1.63644319],
#        [ 7.35120268],
#        [ 6.00156937],
#        [ 7.77278161],
#        [ 5.07079548],
#        [ 7.93219085],
#        [ 4.4538302 ],
#        [ 6.10006957],
#        [ 3.55998572],
#        [ 7.40523057],
#        [ 4.41987278],
#        [ 7.71254328],
#        [ 6.40144971],
#        [ 1.92821045],
#        [ 6.68003623],
#        [ 1.38619994],
#        [ 3.7302067 ],
#        [ 5.68361123],
#        [ 1.00031056],
#        [ 1.21953281],
#        [ 0.61813144],
#        [ 1.90590871],
#        [ 6.50120731],
#        [ 3.99894075],
#        [ 1.64403749],
#        [ 5.10346275],
#        [ 5.86548562],
#        [ 4.35610671],
#        [ 4.89978403],
#        [ 6.95804201],
#        [ 1.92668791],
#        [ 4.81750369],
#        [ 7.48884635],
#        [ 5.8784065 ],
#        [ 4.13283466],
#        [ 5.8630674 ],
#        [ 1.7284699 ],
#        [ 1.1351337 ],
#        [ 6.90671868],
#        [ 5.7341026 ],
#        [ 6.78027425],
#        [ 8.04965064],
#        [ 5.90270612],
#        [ 2.99331279],
#        [ 7.70697601],
#        [ 3.26183861],
#        [ 5.18472496],
#        [ 7.03708853],
#        [ 1.89307215],
#        [ 3.21854139],
#        [ 6.03632478],
#        [ 6.07595419],
#        [ 2.72870992],
#        [ 7.71776934],
#        [ 3.85424802],
#        [ 7.9895543 ],
#        [ 1.57493964],
#        [ 6.85803822],
#        [ 1.41347842],
#        [ 5.8664395 ],
#        [ 6.38397238],
#        [ 7.18097755],
#        [ 7.22984354],
#        [ 6.30388918],
#        [ 0.3888456 ],
#        [ 0.77293965],
#        [ 1.93962918],
#        [ 5.84045955],
#        [ 0.8076739 ],
#        [ 4.74623988],
#        [ 5.79704391],
#        [ 7.47616771],
#        [ 5.35354254],
#        [ 4.56808522],
#        [ 5.37897612],
#        [ 1.91863884],
#        [ 5.92349834],
#        [ 3.6763711 ],
#        [ 6.90027263],
#        [ 6.84050326],
#        [ 7.77157822],
#        [ 4.47891003],
#        [ 3.58637356],
#        [ 5.74929682],
#        [ 5.47475249],
#        [ 4.14559909],
#        [ 7.01529049],
#        [ 7.81560882],
#        [ 2.23746226],
#        [ 2.8795728 ],
#        [ 0.44410114],
#        [ 2.06474886],
#        [ 3.50033459],
#        [ 4.23756773],
#        [ 1.03039361],
#        [ 3.10475785],
#        [ 1.37625994],
#        [ 0.69162641],
#        [ 7.18749207],
#        [ 6.56792097],
#        [ 6.096024  ],
#        [ 4.98518337],
#        [ 2.51337813],
#        [ 4.28926887],
#        [ 0.70725065],
#        [ 5.79497423],
#        [ 3.27186021],
#        [ 3.36345111],
#        [ 6.08595726],
#        [ 3.30226199],
#        [ 5.6726562 ],
#        [ 1.90179839],
#        [ 5.84136888],
#        [ 2.20113146],
#        [ 7.80448591],
#        [ 6.1455668 ],
#        [ 7.6233903 ],
#        [ 3.81225671],
#        [ 6.05595454],
#        [ 5.53082732],
#        [ 6.69093873],
#        [ 4.50498219],
#        [ 5.49298498],
#        [ 7.17315072],
#        [ 5.80814881],
#        [ 5.23295441],
#        [ 7.7121496 ],
#        [ 2.38917668],
#        [ 0.36802163],
#        [ 4.31493318],
#        [ 7.92595971],
#        [ 6.23098912],
#        [ 7.68339976],
#        [ 1.7593125 ],
#        [ 7.93313852],
#        [ 7.32815066],
#        [ 6.02918559],
#        [ 7.93021523],
#        [ 3.68785488],
#        [ 5.40732352],
#        [ 7.6485078 ],
#        [ 2.3876509 ],
#        [ 5.27843812],
#        [ 1.38919092],
#        [ 3.98239164],
#        [ 4.45606741],
#        [ 8.04569557],
#        [ 7.40893366],
#        [ 3.63568893],
#        [ 6.35920356],
#        [ 6.32966014],
#        [ 0.98781465],
#        [ 1.83807153],
#        [ 7.95779425],
#        [ 1.11604887],
#        [ 4.03429826],
#        [ 4.95287038],
#        [ 7.4284456 ],
#        [ 5.90355089],
#        [ 5.95032566],
#        [ 7.66914489],
#        [ 7.14018042],
#        [ 3.81893771],
#        [ 2.85395897],
#        [ 7.26508513],
#        [ 4.33211724],
#        [ 6.97929811],
#        [ 2.68947344],
#        [ 5.89270499],
#        [ 6.4132813 ],
#        [ 7.08246144],
#        [ 4.28925471],
#        [ 1.10855489],
#        [ 7.58027498],
#        [ 4.2962854 ],
#        [ 7.70037979],
#        [ 1.9835144 ],
#        [ 3.51101181],
#        [ 6.46829093]])

# %%
np.mean((y_test_pred-y_test)**2)
# Out:
# 13.481379274336764
